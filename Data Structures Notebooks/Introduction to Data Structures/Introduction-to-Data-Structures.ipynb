# %% [markdown]
# # Introduction to Data Structures

# %% [markdown]
# So now that you have learned how to code in your introduction to computer science course, it is time to learn the theory behind application. There are multiple ways to store data, some ways may be more efficient than others which is why we may not always want to store our data in arrays or lists like in your intro course.
# <h1><center> Enter Data Structures </center> </h1>

# %%
from IPython.display import Image

Image("images/ds.jpg")

# %% [markdown]
# Here is a diagram of some of the data structures we will cover. As you can see, each structure has its drawbacks and benefits. Each data structure can perform four basic operations each of which has a time complexity based on which structure is being used.
# <ul>
#     <li>Access </li>
#     <li>Search </li>
#     <li>Insertion </li>
#     <li>Deletion </li>
# </ul>
# There are also other operations that can be performed on a data structure such as, sorting, merging, and traversing.
