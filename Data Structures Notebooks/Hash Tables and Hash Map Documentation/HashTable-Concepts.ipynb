# %% [markdown]
# # HashTable-Concepts

# %% [markdown]
# The best way to think of a hash table is to think of it as a very fast array. It is a data structure that has indeces and can store values of course. But the most noteworthy aspect of the hash table is its time complexity.

# %% [markdown]
# # Node

# %% [markdown]
# So our original concept of the node involved a container with two properties: a value or data, and a pointer to the next node. This model of the node will not really work for the hash table, so let's modify our definition. Our hash table node will also posses the ability to store data, but it will also have the attribute of having a "key."

# %%
from IPython.display import Image

Image("images/hashNode.jpg")
