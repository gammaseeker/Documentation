# %% [markdown]
# # Hashing

# %% [markdown]
# Before we dive into hash tables, it is important to understand this concept of "hashing." Similar to its conventional english definition, we are given some input, like food, and we "do something" to the food. In conventional cases, we would be chopping up the food, then produce a dish or some output with our pieces.

# %% [markdown]
# So taking this concept let's put this in terms of computer science. We are going to be given some input, and we put that input into a "hash function" noted by $h(x)$. The hash function acts as the process that "chops up" our food. Then the hash function would produce us with our input.

# %%
from IPython.display import Image

Image("images/hashFunction.jpg")

# %% [markdown]
# # Hash Function

# %% [markdown]
# Thankfully, the hash function itself is not a difficult algorithm to implement. The reason being is because the hash function can literally be anything. It can be a math formula, some string manipulation procedure, and it can even just produce the same input it takes in.

# %% [markdown]
# Although this concept may just be coming out of no where (or maybe not), it is very important to understand it because it is the escence of a hash table.
